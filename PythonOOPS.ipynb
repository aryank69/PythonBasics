# %% [markdown]
# **PythonOOPS**
#
#
# Q1. What is Object-Oriented Programming (OOP)?
#  -It structures code around objects, which bundle data (attributes) and behaviors (methods) together.
#
# Q2. What is a class in OOP?
#  -A class is a blueprint or template for creating objects.
#
# Q3. What is an object in OOP?
#  -An object is a fundamental, self-contained unit of code that combines data and the procedures that operate on that data.
#
# Q4. What is the difference between abstraction and encapsulation?
#  -Abstraction hides what an object does (essential features), while encapsulation hides how it does it (implementation details, bundling data/methods)
#
# Q5. What are dunder methods in Python?
#  -Dunder methods, also known as magic methods or special methods, are predefined methods in Python that have double underscores at both the beginning and the end of their names.
#
# Q6.  Explain the concept of inheritance in OOP.
#  -It is a mechanism where a new class (child/derived class) acquires properties and behaviors from an existing class (parent/base class).
#
# Q7. What is polymorphism in OOP?
#  -It means "many forms," allowing a single interface (like a method or function) to represent different underlying actions or objects, enabling objects of different classes to be treated through a common interface while behaving uniquely.
#
# Q8.  How is encapsulation achieved in Python?
#  -Encapsulation in Python is achieved primarily through naming conventions and the use of the @property decorator.
#
# Q9. What is a constructor in Python?
#  -A constructor in Python is a special method used to initialize the attributes (state) of an object immediately after it is created.
#
# Q10. What are class and static methods in Python?
#  -In Python, class methods are methods that are bound to the class and receive the class itself (cls) as an implicit first argument, while static methods are utility functions that belong to the class's namespace but do not receive any implicit first argument.
#
# Q11. What is method overloading in Python?
#  -Method overloading is an object-oriented programming concept that allows a class to have multiple methods with the same name but different parameters.
#
# Q12. What is method overriding in OOP?
#  -Method overriding in OOP lets a child class redefine a method from its parent class, giving it a specific implementation while keeping the same name, parameters, and return type.
#
# Q13. What is a property decorator in Python?
#  -The @property decorator in Python is a built-in feature that allows methods within a class to be accessed like attributes
#
# Q14. Why is polymorphism important in OOP?
#  -It allows developers to write flexible, reusable, and maintainable code by enabling objects of different classes to be treated as objects of a common superclass or interface.
#
# Q15.  What is an abstract class in Python?
#  -An abstract class in Python serves as a blueprint for other classes, defining a common interface and ensuring consistency across related subclasses.
#
# Q16. What are the advantages of OOP?
#  -Object-Oriented Programming (OOP) advantages include modularity, code reusability (inheritance), data security (encapsulation), flexibility (polymorphism), and abstraction.
#
# Q17. What is the difference between a class variable and an instance variable?
#  -A class variable is shared by all instances (objects) of a class, whereas each instance variable is unique to the specific instance it belongs to.
#
# Q18.  What is multiple inheritance in Python?
#  -It allows a child class to inherit attributes and methods from more than one parent class.
#
# Q19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?
#  -In Python, __str__ and __repr__ are "dunder" (double-underscore) methods used to define how an object is represented as a string.
#
# Q20. What is the significance of the ‘super()’ function in Python?
#  -to grant access to methods and properties of a parent or superclass from within a child or subclass.
#
# Q21. What is the significance of the __del__ method in Python?
#  -The __del__ method in Python, also known as the destructor, defines code to be executed when an instance of a class is about to be "destroyed" or garbage-collected.
#
# Q22. What is the difference between @staticmethod and @classmethod in Python?
#  -A @staticmethod is a method that conceptually belongs to the class but doesn't require access to the class instance (self) or the class itself (cls) as a parameter.  A @classmethod is a method that is bound to the class itself, not an instance of the class.
#
# Q23. How does polymorphism work in Python with inheritance?
#  -In Python, polymorphism works with inheritance through method overriding and dynamic typing.
#
# Q24. What is method chaining in Python OOP?
#  -Method chaining in Python OOP is a programming style that allows multiple methods to be called sequentially on a single object in one continuous line of code.
#
# Q25. What is the purpose of the __call__ method in Python?
#  -The purpose of the __call__ method in Python is to allow an instance of a class to be called as a function.

# %%
#1 Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
#that overrides the speak() method to print "Bark!"

class Animal:
  def speak(self):
    print("Animal Speaks")

class Dog(Animal):
  def speak(self):
    print("Bark!")

a = Animal()
b = Dog()
a.speak()
b.speak()
# Out:
# Animal Speaks
# Bark!

# %%
#2 Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
#from it and implement the area() method in both

from abc import ABC, abstractmethod
import math

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

# Test the classes
circle = Circle(5)
rectangle = Rectangle(4, 6)

print(f"Circle area: {circle.area():.2f}")
print(f"Rectangle area: {rectangle.area()}")
# Out:
# Circle area: 78.54
# Rectangle area: 24

# %%
#3 Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
#and further derive a class ElectricCar that adds a battery attribute.

class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type

    def get_type(self):
        return self.type

class Car(Vehicle):
    def __init__(self, vehicle_type, num_doors):
        super().__init__(vehicle_type)
        self.num_doors = num_doors

    def get_doors(self):
        return self.num_doors

class ElectricCar(Car):
    def __init__(self, vehicle_type, num_doors, battery_capacity):
        super().__init__(vehicle_type, num_doors)
        self.battery_capacity = battery_capacity  # kWh

    def get_battery(self):
        return self.battery_capacity

# Test the inheritance chain
tesla = ElectricCar("Electric Car", 4, 75)

print(f"Type: {tesla.get_type()}")
print(f"Doors: {tesla.get_doors()}")
print(f"Battery: {tesla.battery_capacity} kWh")
print(f"Vehicle type: {tesla.type}")
# Out:
# Type: Electric Car
# Doors: 4
# Battery: 75 kWh
# Vehicle type: Electric Car

# %%
#4  Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
#Sparrow and Penguin that override the fly() method.

class Bird:
    def fly(self):
        print("This bird can fly.")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flaps wings and flies high!")

class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly but swims!")

# Polymorphism demonstration
birds = [Sparrow(), Penguin(), Sparrow()]

for bird in birds:
    bird.fly()
# Out:
# Sparrow flaps wings and flies high!
# Penguin cannot fly but swims!
# Sparrow flaps wings and flies high!

# %%
#5 Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
#balance and methods to deposit, withdraw, and check balance.
class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance  # Private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited ${amount:.2f}. New balance: ${self.__balance:.2f}")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if amount > 0:
            if amount <= self.__balance:
                self.__balance -= amount
                print(f"Withdrew ${amount:.2f}. New balance: ${self.__balance:.2f}")
            else:
                print("Insufficient funds.")
        else:
            print("Withdrawal amount must be positive.")

    def get_balance(self):
        return self.__balance

    def __str__(self):
        return f"Account balance: ${self.__balance:.2f}"

# Test the BankAccount
account = BankAccount(1000)
print(account)

account.deposit(500)
account.withdraw(200)
account.withdraw(2000)

print(f"Final balance: ${account.get_balance():.2f}")
# Out:
# Account balance: $1000.00
# Deposited $500.00. New balance: $1500.00
# Withdrew $200.00. New balance: $1300.00
# Insufficient funds.
# Final balance: $1300.00

# %%
#6  Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
#and Piano that implement their own version of play()
class Instrument:
    def play(self):
        print("Instrument is playing.")

class Guitar(Instrument):
    def play(self):
        print("Guitar plays strumming sounds: twang twang twang!")

class Piano(Instrument):
    def play(self):
        print("Piano plays beautiful melody: ding dong plink plonk!")

# Runtime polymorphism demonstration
instruments = [Guitar(), Piano(), Guitar(), Piano()]

print("Playing instruments:")
for instrument in instruments:
    instrument.play()
# Out:
# Playing instruments:
# Guitar plays strumming sounds: twang twang twang!
# Piano plays beautiful melody: ding dong plink plonk!
# Guitar plays strumming sounds: twang twang twang!
# Piano plays beautiful melody: ding dong plink plonk!

# %%
#7 Create a class MathOperations with a class method add_numbers() to add two numbers and a static
#method subtract_numbers() to subtract two numbers.
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# Test the methods
print(MathOperations.add_numbers(10, 5))
print(MathOperations.subtract_numbers(10, 5))

calc = MathOperations()
print(calc.add_numbers(20, 8))
print(calc.subtract_numbers(20, 8))
# Out:
# 15
# 5
# 28
# 12

# %%
#8  Implement a class Person with a class method to count the total number of persons created.
class Person:
    _total_persons = 0  # Class variable to track count

    def __init__(self, name):
        self.name = name
        Person._total_persons += 1  # Increment on each creation

    @classmethod
    def get_total_persons(cls):
        return cls._total_persons

    @classmethod
    def reset_count(cls):
        cls._total_persons = 0

# Test the class
p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")

print(f"Total persons: {Person.get_total_persons()}")
print(f"Alice's name: {p1.name}")

Person.reset_count()
print(f"After reset: {Person.get_total_persons()}")
# Out:
# Total persons: 3
# Alice's name: Alice
# After reset: 0

# %%
#9  Write a class Fraction with attributes numerator and denominator. Override the str method to display the
#fraction as "numerator/denominator".
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

    def __repr__(self):
        return f"Fraction({self.numerator}, {self.denominator})"

# Test the class
f1 = Fraction(3, 4)
f2 = Fraction(22, 7)

print(f1)
print(f2)
print(str(f1))
# Out:
# 3/4
# 22/7
# 3/4

# %%
#10 Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"Vector({self.x}, {self.y})"

    def __repr__(self):
        return f"Vector({self.x}, {self.y})"

# Test vector addition
v1 = Vector(2, 3)
v2 = Vector(4, 5)

v3 = v1 + v2
print(v3)

print(f"v1: {v1}")
print(f"v2: {v2}")
# Out:
# Vector(6, 8)
# v1: Vector(2, 3)
# v2: Vector(4, 5)

# %%
#11 Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
#{name} and I am {age} years old."
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Test the class
person1 = Person("Alice", 25)
person2 = Person("Bob", 30)

person1.greet()
person2.greet()
# Out:
# Hello, my name is Alice and I am 25 years old.
# Hello, my name is Bob and I am 30 years old.

# %%
#12  Implement a class Student with attributes name and grades. Create a method average_grade() to compute
#the average of the grades.
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # List of grades

    def average_grade(self):
        if not self.grades:
            return 0
        return sum(self.grades) / len(self.grades)

    def __str__(self):
        avg = self.average_grade()
        return f"{self.name}: Average grade = {avg:.2f} (Grades: {self.grades})"

# Test the class
student1 = Student("Alice", [85, 92, 78, 95])
student2 = Student("Bob", [88, 76, 90])

print(student1)
print(f"Bob's average: {student2.average_grade():.2f}")
# Out:
# Alice: Average grade = 87.50 (Grades: [85, 92, 78, 95])
# Bob's average: 84.67

# %%
#13  Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.
class Rectangle:
    def __init__(self, width=0, height=0):
        self.width = width
        self.height = height

    def set_dimensions(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

    def __str__(self):
        return f"Rectangle({self.width}x{self.height}), Area: {self.area()}"

# Test the class
rect1 = Rectangle(4, 6)
print(rect1)

rect1.set_dimensions(5, 3)
print(rect1)

rect2 = Rectangle()
rect2.set_dimensions(10, 2)
print(f"rect2 area: {rect2.area()}")
# Out:
# Rectangle(4x6), Area: 24
# Rectangle(5x3), Area: 15
# rect2 area: 20

# %%
#14 Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
#and hourly rate. Create a derived class Manager that adds a bonus to the salary.
class Employee:
    def __init__(self, name, hourly_rate):
        self.name = name
        self.hourly_rate = hourly_rate

    def calculate_salary(self, hours_worked):
        return hours_worked * self.hourly_rate

    def __str__(self):
        return f"{self.name} - Base salary calculator"

class Manager(Employee):
    def __init__(self, name, hourly_rate, bonus):
        super().__init__(name, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self, hours_worked):
        base_salary = super().calculate_salary(hours_worked)
        return base_salary + self.bonus

    def __str__(self):
        return f"{self.name} - Manager (with ${self.bonus} bonus)"

# Test the classes
emp = Employee("John", 20)
mgr = Manager("Alice", 25, 500)

hours = 40
print(f"{emp}: ${emp.calculate_salary(hours)}")
print(f"{mgr}: ${mgr.calculate_salary(hours)}")
# Out:
# John - Base salary calculator: $800
# Alice - Manager (with $500 bonus): $1500

# %%
#15 Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
#calculates the total price of the product.
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

    def __str__(self):
        return f"{self.name}: ${self.price} x {self.quantity} = ${self.total_price()}"

# Test the class
product1 = Product("Laptop", 999.99, 5)
product2 = Product("Mouse", 25.50, 10)

print(product1)
print(product2)
print(f"Total inventory value: ${product1.total_price() + product2.total_price()}")
# Out:
# Laptop: $999.99 x 5 = $4999.95
# Mouse: $25.5 x 10 = $255.0
# Total inventory value: $5254.95

# %%
#16 Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
#implement the sound() method.
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Cow says: Moo!")

class Sheep(Animal):
    def sound(self):
        print("Sheep says: Baa!")

# Test the classes
animals = [Cow(), Sheep(), Cow()]

for animal in animals:
    animal.sound()
# Out:
# Cow says: Moo!
# Sheep says: Baa!
# Cow says: Moo!

# %%
#17 Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
#returns a formatted string with the book's details.
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"

    def __str__(self):
        return self.get_book_info()

# Test the class
book1 = Book("1984", "George Orwell", 1949)
book2 = Book("To Kill a Mockingbird", "Harper Lee", 1960)

print(book1.get_book_info())
print(book2)
print(f"Library has: {book1.get_book_info()}")
# Out:
# '1984' by George Orwell, published in 1949
# 'To Kill a Mockingbird' by Harper Lee, published in 1960
# Library has: '1984' by George Orwell, published in 1949

# %%
#18 Create a class House with attributes address and price. Create a derived class Mansion that adds an
#attribute number_of_rooms.
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def get_info(self):
        return f"{self.address} - ${self.price:,}"

    def __str__(self):
        return self.get_info()

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def get_info(self):
        base_info = super().get_info()
        return f"{base_info}, {self.number_of_rooms} rooms"

    def __str__(self):
        return self.get_info()

# Test the classes
house = House("123 Main St", 250000)
mansion = Mansion("888 Beverly Hills", 5000000, 12)

print(house)
print(mansion)
print(f"Mansion rooms: {mansion.number_of_rooms}")
# Out:
# 123 Main St - $250,000
# 888 Beverly Hills - $5,000,000, 12 rooms
# Mansion rooms: 12
